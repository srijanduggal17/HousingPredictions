# %% [markdown]
# ### Messing around with the Fred API

# %%
# Import stuff
import pandas as pd
import numpy as np
import time
import requests
import json

# %% [markdown]
# K: number of features
# T: number of timesteps
# N: number of examples
#
# At the end of the day, we want our dataset in the following format (NxTxK):
# - each example will have an associated county and timeframe
# - each example will have inputs (KxT)
# - each example will have targets (1xT)

# %% [markdown]
# #### How the data is organized from their API:
# - series: what we might think of as a dataset. Has (time, value) pairs
# - category: This is a general bucket containing many series or containing child categories
#
# #### Individual categories:
# - county: each county has a unique id
# - msa: each metro statistical area has a unique id and will be associated with many counties
# - state: each state has a unique id and will be associated with many state
# - country: USA has a unique id and will be associated with all counties
#
# Series: each series has a unique id and will be related to a geography type (county, metro statistical area(MSA), state, country) via id

# %% [markdown]
# #### Getting the actual data
# We can the feature matrix for one example as follows:
# - Choose a county
# - Request all series titles for the category_id corresponding to the county
# - Request the full series for each title from before (we can fill some of our KxT)
# - Get the state that the county is in
# - Include the features for the state (fill in some more of our KxT)
# - Include the features for the country (fill in some more of our KxT)
# - Get the msa associated with the county
# - Include the features for the msa (fill in the rest of our KxT)
#
# To get the features for each state:
# - Request the series_ids for the category_id corresponding to the state
#
# To get the features for the country:
# - Request the series_ids for the category_id corresponding to the country
#
# To get the features for each msa:
# - Request the series_ids for the category_id corresponding to the msa

# %%
#Get category id for all states

params = {
            'category_id':27281,
            'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
            'file_type': 'json'
         }

r = requests.get(url = 'https://api.stlouisfed.org/fred/category/children', params=params) 
res = r.json()

states = res['categories']

for state in states:
    print(state)
# Out:
# {'id': 27282, 'name': 'Alabama', 'parent_id': 27281}
# {'id': 27283, 'name': 'Alaska', 'parent_id': 27281}
# {'id': 27284, 'name': 'Arizona', 'parent_id': 27281}
# {'id': 149, 'name': 'Arkansas', 'parent_id': 27281}
# {'id': 27286, 'name': 'California', 'parent_id': 27281}
# {'id': 27287, 'name': 'Colorado', 'parent_id': 27281}
# {'id': 27288, 'name': 'Connecticut', 'parent_id': 27281}
# {'id': 27289, 'name': 'Delaware', 'parent_id': 27281}
# {'id': 27290, 'name': 'District of Columbia', 'parent_id': 27281}
# {'id': 27291, 'name': 'Florida', 'parent_id': 27281}
# {'id': 27292, 'name': 'Georgia', 'parent_id': 27281}
# {'id': 27293, 'name': 'Hawaii', 'parent_id': 27281}
# {'id': 27294, 'name': 'Idaho', 'parent_id': 27281}
# {'id': 150, 'name': 'Illinois', 'parent_id': 27281}
# {'id': 151, 'name': 'Indiana', 'parent_id': 27281}
# {'id': 27297, 'name': 'Iowa', 'parent_id': 27281}
# {'id': 27298, 'name': 'Kansas', 'parent_id': 27281}
# {'id': 152, 'name': 'Kentucky', 'parent_id': 27281}
# {'id': 27300, 'name': 'Louisiana', 'parent_id': 27281}
# {'id': 27301, 'name': 'Maine', 'parent_id': 27281}
# {'id': 27302, 'name': 'Maryland', 'parent_id': 27281}
# {'id': 27303, 'name': 'Massachusetts', 'parent_id': 27281}
# {'id': 27304, 'name': 'Michigan', 'parent_id': 27281}
# {'id': 27305, 'name': 'Minnesota', 'parent_id': 27281}
# {'id': 153, 'name': 'Mississippi', 'parent_id': 27281}
# {'id': 154, 'name': 'Missouri', 'parent_id': 27281}
# {'id': 27308, 'name': 'Montana', 'parent_id': 27281}
# {'id': 27309, 'name': 'Nebraska', 'parent_id': 27281}
# {'id': 27310, 'name': 'Nevada', 'parent_id': 27281}
# {'id': 27311, 'name': 'New Hampshire', 'parent_id': 27281}
# {'id': 27312, 'name': 'New Jersey', 'parent_id': 27281}
# {'id': 27313, 'name': 'New Mexico', 'parent_id': 27281}
# {'id': 27314, 'name': 'New York', 'parent_id': 27281}
# {'id': 27315, 'name': 'North Carolina', 'parent_id': 27281}
# {'id': 27316, 'name': 'North Dakota', 'parent_id': 27281}
# {'id': 27317, 'name': 'Ohio', 'parent_id': 27281}
# {'id': 27318, 'name': 'Oklahoma', 'parent_id': 27281}
# {'id': 27319, 'name': 'Oregon', 'parent_id': 27281}
# {'id': 27320, 'name': 'Pennsylvania', 'parent_id': 27281}
# {'id': 33504, 'name': 'Puerto Rico', 'parent_id': 27281}
# {'id': 27322, 'name': 'Rhode Island', 'parent_id': 27281}
# {'id': 27323, 'name': 'South Carolina', 'parent_id': 27281}
# {'id': 27324, 'name': 'South Dakota', 'parent_id': 27281}
# {'id': 193, 'name': 'Tennessee', 'parent_id': 27281}
# {'id': 27326, 'name': 'Texas', 'parent_id': 27281}
# {'id': 27328, 'name': 'Utah', 'parent_id': 27281}
# {'id': 27329, 'name': 'Vermont', 'parent_id': 27281}
# {'id': 33605, 'name': 'Virgin Islands', 'parent_id': 27281}
# {'id': 27330, 'name': 'Virginia', 'parent_id': 27281}
# {'id': 27332, 'name': 'West Virginia', 'parent_id': 27281}
# {'id': 27331, 'name': 'Washington', 'parent_id': 27281}
# {'id': 27333, 'name': 'Wisconsin', 'parent_id': 27281}
# {'id': 27334, 'name': 'Wyoming', 'parent_id': 27281}

# %%
# This first request is just an intermediate link that we have to
# make for each state in order to access its counties
state_id = states[0]['id']
state_name = states[0]['name']
params = {
    'category_id': state_id,
    'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
    'file_type': 'json'
}
r = requests.get(url = 'https://api.stlouisfed.org/fred/category/children', params=params)
res = r.json()

state_counties_id = None
for child in res['categories']:
    if child['name'] == 'Counties':
        state_counties_id = child['id']
        
print(state_counties_id)
# Out:
# 27335

# %%
# Here we actually get the counties
params = {
    'category_id': state_counties_id,
    'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
    'file_type': 'json'
}
r = requests.get(url = 'https://api.stlouisfed.org/fred/category/children', params=params)
res = r.json()
print(json.dumps(res['categories'], indent=4))

counties_in_state = res['categories']
# Out:
# [
#     {
#         "id": 27336,
#         "name": "Autauga County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27337,
#         "name": "Baldwin County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27338,
#         "name": "Barbour County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27339,
#         "name": "Bibb County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27340,
#         "name": "Blount County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27341,
#         "name": "Bullock County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27342,
#         "name": "Butler County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27343,
#         "name": "Calhoun County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27344,
#         "name": "Chambers County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27345,
#         "name": "Cherokee County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27346,
#         "name": "Chilton County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27347,
#         "name": "Choctaw County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27348,
#         "name": "Clarke County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27349,
#         "name": "Clay County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27350,
#         "name": "Cleburne County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27351,
#         "name": "Coffee County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27352,
#         "name": "Colbert County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27353,
#         "name": "Conecuh County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27354,
#         "name": "Coosa County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27355,
#         "name": "Covington County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27356,
#         "name": "Crenshaw County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27357,
#         "name": "Cullman County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27358,
#         "name": "Dale County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27359,
#         "name": "Dallas County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27360,
#         "name": "De Kalb County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27361,
#         "name": "Elmore County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27362,
#         "name": "Escambia County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27363,
#         "name": "Etowah County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27364,
#         "name": "Fayette County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27365,
#         "name": "Franklin County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27366,
#         "name": "Geneva County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27367,
#         "name": "Greene County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27368,
#         "name": "Hale County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27369,
#         "name": "Henry County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27370,
#         "name": "Houston County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27371,
#         "name": "Jackson County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27372,
#         "name": "Jefferson County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27373,
#         "name": "Lamar County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27374,
#         "name": "Lauderdale County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27375,
#         "name": "Lawrence County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27376,
#         "name": "Lee County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27377,
#         "name": "Limestone County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27378,
#         "name": "Lowndes County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27379,
#         "name": "Macon County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27380,
#         "name": "Madison County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27381,
#         "name": "Marengo County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27382,
#         "name": "Marion County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27383,
#         "name": "Marshall County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27384,
#         "name": "Mobile County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27385,
#         "name": "Monroe County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27386,
#         "name": "Montgomery County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27387,
#         "name": "Morgan County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27388,
#         "name": "Perry County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27389,
#         "name": "Pickens County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27390,
#         "name": "Pike County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27391,
#         "name": "Randolph County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27392,
#         "name": "Russell County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27393,
#         "name": "Shelby County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27394,
#         "name": "St. Clair County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27395,
#         "name": "Sumter County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27396,
#         "name": "Talladega County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27397,
#         "name": "Tallapoosa County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27398,
#         "name": "Tuscaloosa County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27399,
#         "name": "Walker County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27400,
#         "name": "Washington County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27401,
#         "name": "Wilcox County, AL",
#         "parent_id": 27335
#     },
#     {
#         "id": 27402,
#         "name": "Winston County, AL",
#         "parent_id": 27335
#     }
# ]

# %%
# Get the series titles for a county
county_id = counties_in_state[0]['id']
county_name = counties_in_state[0]['name']
print(county_name)
params = {
    'category_id': county_id,
    'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
    'file_type': 'json'
}
r = requests.get(url = 'https://api.stlouisfed.org/fred/category/series', params=params)
res = r.json()
series_for_county = res['seriess']
print(json.dumps(series_for_county[0:5], indent=4))
# Out:
# Autauga County, AL
# [
#     {
#         "id": "2020RATIO001001",
#         "realtime_start": "2020-04-10",
#         "realtime_end": "2020-04-10",
#         "title": "Income Inequality in Autauga County, AL",
#         "observation_start": "2010-01-01",
#         "observation_end": "2018-01-01",
#         "frequency": "Annual",
#         "frequency_short": "A",
#         "units": "Ratio",
#         "units_short": "Ratio",
#         "seasonal_adjustment": "Not Seasonally Adjusted",
#         "seasonal_adjustment_short": "NSA",
#         "last_updated": "2019-12-19 11:06:37-06",
#         "popularity": 1,
#         "group_popularity": 1,
#         "notes": "This data represents the ratio of the mean income for the highest quintile (top 20 percent) of earners divided by the mean income of the lowest quintile (bottom 20 percent) of earners in a particular county. Multiyear estimates from the American Community Survey (ACS) are \"period\" estimates derived from a data sample collected over a period of time, as opposed to \"point-in-time\" estimates such as those from past decennial censuses. ACS 5-year estimate includes data collected over a 60-month period. The date of the data is the end of the 5-year period. For example, a value dated 2014 represents data from 2010 to 2014. However, they  do  not  describe  any  specific day, month, or year within that time period.\n\nMultiyear  estimates  require  some  considerations  that  single-year  estimates  do  not.  For  example,  multiyear  estimates released in consecutive years consist mostly of overlapping years and shared data. The 2010\u20132014 ACS 5-year estimates share sample data from 2011 through 2014 with the 2011\u20132015 ACS 5-year estimates. Because of this overlap, users should use extreme caution in making comparisons with consecutive years of multiyear estimates.\n\nPlease see \"Section 3: Understanding and Using ACS Single-Year and Multiyear Estimates\" on publication page 13 (file page 19) of the 2018 ACS General Handbook for a more thorough clarification. https://www.census.gov/content/dam/Census/library/publications/2018/acs/acs_general_handbook_2018.pdf"
#     },
#     {
#         "id": "ACTLISCOU1001",
#         "realtime_start": "2020-04-10",
#         "realtime_end": "2020-04-10",
#         "title": "Housing Inventory: Active Listing Count in Autauga County, AL",
#         "observation_start": "2016-07-01",
#         "observation_end": "2020-03-01",
#         "frequency": "Monthly",
#         "frequency_short": "M",
#         "units": "Level",
#         "units_short": "Level",
#         "seasonal_adjustment": "Not Seasonally Adjusted",
#         "seasonal_adjustment_short": "NSA",
#         "last_updated": "2020-04-02 18:01:15-05",
#         "popularity": 0,
#         "group_popularity": 0,
#         "notes": "The count of active single-family and condo/townhome listings for a given market during the specified month (excludes pending listings)."
#     },
#     {
#         "id": "ACTLISCOUMM1001",
#         "realtime_start": "2020-04-10",
#         "realtime_end": "2020-04-10",
#         "title": "Housing Inventory: Active Listing Count Month-Over-Month in Autauga County, AL",
#         "observation_start": "2017-07-01",
#         "observation_end": "2020-03-01",
#         "frequency": "Monthly",
#         "frequency_short": "M",
#         "units": "Percent",
#         "units_short": "%",
#         "seasonal_adjustment": "Not Seasonally Adjusted",
#         "seasonal_adjustment_short": "NSA",
#         "last_updated": "2020-04-02 18:09:06-05",
#         "popularity": 0,
#         "group_popularity": 0,
#         "notes": "The count of active single-family and condo/townhome listings for a given market during the specified month (excludes pending listings)."
#     },
#     {
#         "id": "ACTLISCOUYY1001",
#         "realtime_start": "2020-04-10",
#         "realtime_end": "2020-04-10",
#         "title": "Housing Inventory: Active Listing Count Year-Over-Year in Autauga County, AL",
#         "observation_start": "2017-07-01",
#         "observation_end": "2020-03-01",
#         "frequency": "Monthly",
#         "frequency_short": "M",
#         "units": "Percent",
#         "units_short": "%",
#         "seasonal_adjustment": "Not Seasonally Adjusted",
#         "seasonal_adjustment_short": "NSA",
#         "last_updated": "2020-04-02 18:04:31-05",
#         "popularity": 0,
#         "group_popularity": 0,
#         "notes": "The count of active single-family and condo/townhome listings for a given market during the specified month (excludes pending listings)."
#     },
#     {
#         "id": "ALAUTA1LFN",
#         "realtime_start": "2020-04-10",
#         "realtime_end": "2020-04-10",
#         "title": "Civilian Labor Force in Autauga County, AL",
#         "observation_start": "1990-01-01",
#         "observation_end": "2020-02-01",
#         "frequency": "Monthly",
#         "frequency_short": "M",
#         "units": "Persons",
#         "units_short": "Persons",
#         "seasonal_adjustment": "Not Seasonally Adjusted",
#         "seasonal_adjustment_short": "NSA",
#         "last_updated": "2020-04-08 10:16:44-05",
#         "popularity": 1,
#         "group_popularity": 1
#     }
# ]

# %%
# Get the observations for a series
current_series = series_for_county[0]
series_id = current_series['id']

params = {
    'series_id': series_id,
    'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
    'file_type': 'json'
}
r = requests.get(url = 'https://api.stlouisfed.org/fred/series/observations', params=params)
res1 = r.json()

# %%
print(series_id)
print(json.dumps(res1, indent=4))
# Out:
# 2020RATIO001001
# {
#     "realtime_start": "2020-04-10",
#     "realtime_end": "2020-04-10",
#     "observation_start": "1600-01-01",
#     "observation_end": "9999-12-31",
#     "units": "lin",
#     "output_type": 1,
#     "file_type": "json",
#     "order_by": "observation_date",
#     "sort_order": "asc",
#     "count": 9,
#     "offset": 0,
#     "limit": 100000,
#     "observations": [
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2010-01-01",
#             "value": "10.938249904470768"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2011-01-01",
#             "value": "10.690538383398636"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2012-01-01",
#             "value": "11.112458162885831"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2013-01-01",
#             "value": "10.792501714546978"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2014-01-01",
#             "value": "11.025451749327182"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2015-01-01",
#             "value": "11.869328638873329"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-01-01",
#             "value": "12.374940823733628"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-01-01",
#             "value": "13.917740895907187"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-01-01",
#             "value": "15.725662194702442"
#         }
#     ]
# }

# %%
# Get the observations for another series
next_series = series_for_county[1]
series_id = next_series['id']

params = {
    'series_id': series_id,
    'api_key': 'e76fcf746d3ca3cc025c0803dd212fc8',
    'file_type': 'json'
}
r = requests.get(url = 'https://api.stlouisfed.org/fred/series/observations', params=params)
res2 = r.json()
print(json.dumps(res2, indent=4))
# Out:
# {
#     "realtime_start": "2020-04-10",
#     "realtime_end": "2020-04-10",
#     "observation_start": "1600-01-01",
#     "observation_end": "9999-12-31",
#     "units": "lin",
#     "output_type": 1,
#     "file_type": "json",
#     "order_by": "observation_date",
#     "sort_order": "asc",
#     "count": 45,
#     "offset": 0,
#     "limit": 100000,
#     "observations": [
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-07-01",
#             "value": "269.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-08-01",
#             "value": "258.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-09-01",
#             "value": "252.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-10-01",
#             "value": "231.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-11-01",
#             "value": "210.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2016-12-01",
#             "value": "195.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-01-01",
#             "value": "177.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-02-01",
#             "value": "193.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-03-01",
#             "value": "203.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-04-01",
#             "value": "216.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-05-01",
#             "value": "224.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-06-01",
#             "value": "228.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-07-01",
#             "value": "212.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-08-01",
#             "value": "204.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-09-01",
#             "value": "222.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-10-01",
#             "value": "233.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-11-01",
#             "value": "211.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2017-12-01",
#             "value": "194.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-01-01",
#             "value": "192.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-02-01",
#             "value": "195.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-03-01",
#             "value": "205.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-04-01",
#             "value": "224.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-05-01",
#             "value": "219.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-06-01",
#             "value": "228.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-07-01",
#             "value": "227.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-08-01",
#             "value": "202.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-09-01",
#             "value": "197.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-10-01",
#             "value": "175.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-11-01",
#             "value": "177.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2018-12-01",
#             "value": "184.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-01-01",
#             "value": "181.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-02-01",
#             "value": "183.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-03-01",
#             "value": "182.5"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-04-01",
#             "value": "182.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-05-01",
#             "value": "176.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-06-01",
#             "value": "179.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-07-01",
#             "value": "175.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-08-01",
#             "value": "170.5"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-09-01",
#             "value": "166.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-10-01",
#             "value": "160.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-11-01",
#             "value": "172.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2019-12-01",
#             "value": "168.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2020-01-01",
#             "value": "155.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2020-02-01",
#             "value": "147.0"
#         },
#         {
#             "realtime_start": "2020-04-10",
#             "realtime_end": "2020-04-10",
#             "date": "2020-03-01",
#             "value": "141.0"
#         }
#     ]
# }

# %%
# Combine two sets of observations into one DataFrame
county_data = pd.DataFrame(columns=['date'])

series_title = series_for_county[0]['title']

df_series_1 = pd.DataFrame(res1['observations'])
df_series_1.rename(columns={'value': get_series_name(county_name, series_title)}, inplace=True)
df_series_1.drop(['realtime_start', 'realtime_end'], axis=1, inplace=True)
# print(df_series_1.head())
county_data = pd.merge(county_data, df_series_1, how='outer', on=['date'])
county_data.set_index('date', inplace=True)
series_title = series_for_county[1]['title']

df_series_2 = pd.DataFrame(res2['observations'])
df_series_2.rename(columns={'value': get_series_name(county_name, series_title)}, inplace=True)
df_series_2.drop(['realtime_start', 'realtime_end'], axis=1, inplace=True)
county_data = pd.merge(county_data, df_series_2, how='outer', on=['date'])
county_data.set_index('date', inplace=True)
print(county_data)
# Out:
#              Income Inequality Housing Inventory: Active Listing Count
# date
# 2010-01-01  10.938249904470768                                     NaN
# 2011-01-01  10.690538383398636                                     NaN
# 2012-01-01  11.112458162885831                                     NaN
# 2013-01-01  10.792501714546978                                     NaN
# 2014-01-01  11.025451749327182                                     NaN
# 2015-01-01  11.869328638873329                                     NaN
# 2016-01-01  12.374940823733628                                     NaN
# 2017-01-01  13.917740895907187                                   177.0
# 2018-01-01  15.725662194702442                                   192.0
# 2016-07-01                 NaN                                   269.0
# 2016-08-01                 NaN                                   258.0
# 2016-09-01                 NaN                                   252.0
# 2016-10-01                 NaN                                   231.0
# 2016-11-01                 NaN                                   210.0
# 2016-12-01                 NaN                                   195.0
# 2017-02-01                 NaN                                   193.0
# 2017-03-01                 NaN                                   203.0
# 2017-04-01                 NaN                                   216.0
# 2017-05-01                 NaN                                   224.0
# 2017-06-01                 NaN                                   228.0
# 2017-07-01                 NaN                                   212.0
# 2017-08-01                 NaN                                   204.0
# 2017-09-01                 NaN                                   222.0
# 2017-10-01                 NaN                                   233.0
# 2017-11-01                 NaN                                   211.0
# 2017-12-01                 NaN                                   194.0
# 2018-02-01                 NaN                                   195.0
# 2018-03-01                 NaN                                   205.0
# 2018-04-01                 NaN                                   224.0
# 2018-05-01                 NaN                                   219.0
# 2018-06-01                 NaN                                   228.0
# 2018-07-01                 NaN                                   227.0
# 2018-08-01                 NaN                                   202.0
# 2018-09-01                 NaN                                   197.0
# 2018-10-01                 NaN                                   175.0
# 2018-11-01                 NaN                                   177.0
# 2018-12-01                 NaN                                   184.0
# 2019-01-01                 NaN                                   181.0
# 2019-02-01                 NaN                                   183.0
# 2019-03-01                 NaN                                   182.5
# 2019-04-01                 NaN                                   182.0
# 2019-05-01                 NaN                                   176.0
# 2019-06-01                 NaN                                   179.0
# 2019-07-01                 NaN                                   175.0
# 2019-08-01                 NaN                                   170.5
# 2019-09-01                 NaN                                   166.0
# 2019-10-01                 NaN                                   160.0
# 2019-11-01                 NaN                                   172.0
# 2019-12-01                 NaN                                   168.0
# 2020-01-01                 NaN                                   155.0
# 2020-02-01                 NaN                                   147.0
# 2020-03-01                 NaN                                   141.0
