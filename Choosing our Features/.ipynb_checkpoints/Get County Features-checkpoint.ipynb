# %%
import pandas as pd
import numpy as np
import time
import json
import requests
from datetime import date
from matplotlib import pyplot as plt
import datetime
import timeit

# %%
# ADD API KEYS HERE - they will all be used in API calls as to avoid rate limiting
api_keys = ['0a9d962918e369aa52bf64266bf11f57',
            'e76fcf746d3ca3cc025c0803dd212fc8',
            '09ce82c5913affec7a666545f702b782',
            '1dcd3965c80843f98a1b195c8ca6b486',
            '3328f91bacb678034ddef11caace433e',
            '2c53f22c76b09beaefd3130d5d1b0105']

# %%
county_level_feat = pd.read_csv('county_features_final.csv')

# %%
# chosen_county_feat = np.unique(county_level_feat.title.values)
# print(np.unique(county_level_feat['frequency']))
# print(len(chosen_county_feat))
# print(chosen_county_feat)

# %%
county_level_feat.head()
# Out:
#    Unnamed: 0 frequency               id observation_end observation_start  \
# 0           0    Annual  2020RATIO001001      2018-01-01        2010-01-01
# 1           1   Monthly       ALAUTA1LFN      2020-02-01        1990-01-01
# 2           2    Annual       ALAUTA1POP      2019-01-01        1970-01-01
# 3           3   Monthly       ALAUTA1URN      2020-02-01        1990-01-01
# 4           4    Annual   ATNHPIUS01001A      2018-01-01        1986-01-01
#
#        seasonal_adjustment                               title  \
# 0  Not Seasonally Adjusted                   Income Inequality
# 1  Not Seasonally Adjusted                Civilian Labor Force
# 2  Not Seasonally Adjusted                 Resident Population
# 3  Not Seasonally Adjusted                   Unemployment Rate
# 4  Not Seasonally Adjusted  All-Transactions House Price Index
#
#                   units  county_id  num_months
# 0                 Ratio      27336          96
# 1               Persons      27336         361
# 2  Thousands of Persons      27336         588
# 3               Percent      27336         361
# 4        Index 2000=100      27336         384

# %%
county_level_feat = county_level_feat.sort_values(["county_id", "id"])

counties_list = np.unique(county_level_feat['county_id'].values)
feat_ids = county_level_feat['id'].values

# print(list(counties_list).index(29200))

print(len(counties_list))
# to_retry = np.array([29352,29482,29869])
# Out:
# 1985

# %%
# edit the start and end variables to determine which counties to get data for
start = 1914
end = 1985
count = start

cur_key_num = 0
num_keys = len(api_keys)
failed_ids = []
for county_id in counties_list[start:end]:
    start_time = timeit.default_timer()
    try:
        time.sleep(.1)
        params = {
            'category_id': county_id,
            'api_key': api_keys[cur_key_num],
            'file_type': 'json'
        }
        cur_key_num = (cur_key_num + 1) % num_keys

        r = requests.get(url = 'https://api.stlouisfed.org/fred/category/series', params=params)
        res = r.json()
        # Get the observations for a series
        seriess = res['seriess']
        res2 = []
        for series in range(len(seriess)):
            current_series = seriess[series]
            series_id = current_series['id']
            freq = current_series['frequency']

            params = {
                'series_id': series_id,
                'api_key': api_keys[cur_key_num],
                'file_type': 'json'
            }
            cur_key_num = (cur_key_num + 1) % num_keys
            time.sleep(.1)

            r = requests.get(url = 'https://api.stlouisfed.org/fred/series/observations', params=params)

            res1 = r.json()
            res1["observations"] = [i for i in res1["observations"] if not (int(i["date"][0:4]) < 2010 or int(i["date"][0:4]) > 2017)]
                
            for val in res1["observations"]:
                del val["realtime_start"]
                del val["realtime_end"]

            if series_id in feat_ids:
                for val in res1['observations']:
                    if (freq == "Annual"):
                        val['feature'] = series_id
                        res2 += [val]
                        for i in range(2, 13):
                            if i < 10:
                                string = '0' + str(i)
                            else:
                                string = str(i)
                            dict_to_add = {}
                            dict_to_add['feature'] = series_id
                            dict_to_add['date'] = val['date'][0:5] + string + val['date'][7:10]
                            dict_to_add['value'] = val['value']
                            res2 += [dict_to_add]
                    elif (freq == "Quarterly"):
                        val['feature'] = series_id
                        res2 += [val]
                        for i in range(1, 3):
                            cur_date = int(val['date'][5:7])
                            date = i + cur_date
                            if date < 10:
                                date = '0' + str(date)
                            else:
                                date = str(date)

                            dict_to_add = {}
                            dict_to_add['feature'] = series_id
                            dict_to_add['date'] = val['date'][0:5] + date + val['date'][7:10]
                            dict_to_add['value'] = val['value']
                            res2 += [dict_to_add]
                    else: #monthly
                        val['feature'] = series_id
                        res2 += [val]

        dates = []
        for i in range(96):
            dates += [res2[i]['date']]

        res3 = {}
        for val in res2:
            if val['feature'] not in res3.keys():
                # new thing
                res3[val['feature']] = [val['value']]
            else:
                res3[val['feature']] += [val['value']]

        for feat in res3:
            if len(res3[feat]) != 96:
                del res3[feat]

        name = 'county_data/' + str(county_id) + '.csv'

        data = pd.DataFrame(res3, index=dates)
        data.to_csv(name)
        elapsed = timeit.default_timer() - start_time
        print('%d. csv written, county id: %s \t time elapsed: %f' %(count, county_id, elapsed))
        count += 1
        
    except:
        print('County ID Failed, rate limited: %s' %(county_id))
        failed_ids += [county_id]
print('Failed counties:')
if (len(failed_ids)) == 0:
    print("None")
else:
    for i in failed_ids:
        print(i)
# Out:
# 1914. csv written, county id: 30453 	 time elapsed: 42.607204
# 1915. csv written, county id: 30454 	 time elapsed: 110.755375
# 1916. csv written, county id: 30455 	 time elapsed: 46.640505
# 1917. csv written, county id: 30456 	 time elapsed: 50.932452
# 1918. csv written, county id: 30457 	 time elapsed: 55.635099
# 1919. csv written, county id: 30459 	 time elapsed: 53.382909
# 1920. csv written, county id: 30460 	 time elapsed: 75.379434
# 1921. csv written, county id: 30461 	 time elapsed: 41.465914
# 1922. csv written, county id: 30462 	 time elapsed: 69.526356
# 1923. csv written, county id: 30463 	 time elapsed: 34.087197
# 1924. csv written, county id: 30464 	 time elapsed: 64.645572
# 1925. csv written, county id: 30465 	 time elapsed: 36.468822
# 1926. csv written, county id: 30466 	 time elapsed: 36.657495
# 1927. csv written, county id: 30467 	 time elapsed: 39.162238
# 1928. csv written, county id: 30468 	 time elapsed: 64.956128
# 1929. csv written, county id: 30469 	 time elapsed: 62.272445
# 1930. csv written, county id: 30470 	 time elapsed: 34.107411
# 1931. csv written, county id: 30471 	 time elapsed: 36.649599
# 1932. csv written, county id: 30473 	 time elapsed: 61.372264
# 1933. csv written, county id: 30474 	 time elapsed: 35.580068
# 1934. csv written, county id: 30475 	 time elapsed: 38.873885
# 1935. csv written, county id: 30476 	 time elapsed: 39.439999
# 1936. csv written, county id: 30477 	 time elapsed: 66.812892
# 1937. csv written, county id: 30478 	 time elapsed: 70.094435
# 1938. csv written, county id: 30479 	 time elapsed: 37.987093
# 1939. csv written, county id: 30480 	 time elapsed: 37.154806
# 1940. csv written, county id: 30481 	 time elapsed: 35.719465
# 1941. csv written, county id: 30482 	 time elapsed: 60.596399
# 1942. csv written, county id: 30483 	 time elapsed: 35.427608
# 1943. csv written, county id: 30484 	 time elapsed: 64.986298
# 1944. csv written, county id: 30485 	 time elapsed: 37.526326
# 1945. csv written, county id: 30486 	 time elapsed: 65.955672
# 1946. csv written, county id: 30487 	 time elapsed: 35.081924
# 1947. csv written, county id: 30488 	 time elapsed: 61.229953
# 1948. csv written, county id: 30489 	 time elapsed: 36.380640
# 1949. csv written, county id: 30490 	 time elapsed: 38.099206
# 1950. csv written, county id: 30491 	 time elapsed: 61.593935
# 1951. csv written, county id: 30492 	 time elapsed: 65.584984
# 1952. csv written, county id: 30493 	 time elapsed: 36.586608
# 1953. csv written, county id: 30494 	 time elapsed: 34.812090
# 1954. csv written, county id: 30495 	 time elapsed: 37.213439
# 1955. csv written, county id: 30496 	 time elapsed: 36.295817
# 1956. csv written, county id: 30497 	 time elapsed: 62.640934
# 1957. csv written, county id: 30498 	 time elapsed: 36.644888
# 1958. csv written, county id: 30499 	 time elapsed: 62.972796
# 1959. csv written, county id: 30500 	 time elapsed: 65.367014
# 1960. csv written, county id: 30501 	 time elapsed: 37.802881
# 1961. csv written, county id: 30502 	 time elapsed: 37.017070
# 1962. csv written, county id: 30503 	 time elapsed: 64.812435
# 1963. csv written, county id: 30504 	 time elapsed: 63.409600
# 1964. csv written, county id: 30506 	 time elapsed: 35.716261
# 1965. csv written, county id: 30507 	 time elapsed: 36.034339
# 1966. csv written, county id: 30508 	 time elapsed: 38.058548
# 1967. csv written, county id: 30509 	 time elapsed: 37.623148
# 1968. csv written, county id: 30511 	 time elapsed: 38.834150
# 1969. csv written, county id: 30512 	 time elapsed: 39.030928
# 1970. csv written, county id: 30513 	 time elapsed: 42.239713
# 1971. csv written, county id: 30514 	 time elapsed: 34.505185
# 1972. csv written, county id: 30515 	 time elapsed: 39.292890
# 1973. csv written, county id: 30516 	 time elapsed: 64.526008
# 1974. csv written, county id: 30517 	 time elapsed: 35.682591
# 1975. csv written, county id: 30518 	 time elapsed: 66.370894
# 1976. csv written, county id: 30520 	 time elapsed: 36.824140
# 1977. csv written, county id: 30521 	 time elapsed: 36.623465
# 1978. csv written, county id: 30522 	 time elapsed: 38.313387
# 1979. csv written, county id: 30523 	 time elapsed: 36.946739
# 1980. csv written, county id: 30524 	 time elapsed: 34.274772
# 1981. csv written, county id: 30526 	 time elapsed: 39.922075
# 1982. csv written, county id: 30527 	 time elapsed: 37.176560
# 1983. csv written, county id: 30528 	 time elapsed: 37.805314
# 1984. csv written, county id: 32078 	 time elapsed: 71.709069
# Failed counties:
# None

# %%
import os
csvs = os.listdir('county_data')

for idx, elem in enumerate(csvs):
    csvs[idx] = int(elem[:-4])
csvs.sort()
# print(csvs)
# print(list(counties_list))
counties = list(counties_list)
counties.sort()
print(len(csvs))
print(len(counties))
for i in range(len(csvs)):
    if counties[i] != csvs[i]:
        print(counties[i], csvs[i], counties.index(csvs[i]), i)

# print(counties.index(29342))

# print(counties.index(29673))
# Out:
# 1985
# 1985

# %%
county_level_feat.head()
title_dict = {}
for index, row in county_level_feat.iterrows():
    title_dict[row["id"]] = row['title']
# print(len(np.unique(county_level_feat['title'])))
# for item in title_dict:
#     print(item, title_dict[item])
# Out:
# 73

# %%
# code to rename the columns in the csvs
import os
csvs = os.listdir('county_data')

start_time = timeit.default_timer()

# print(csvs)
for idx, file in enumerate(csvs):
    df = pd.read_csv(('county_data/' + file), index_col=0)
    df.rename(columns=title_dict, inplace=True)
    df = df.reindex(sorted(df.columns), axis=1)
    df.to_csv(('county_data/' + file))
    if (idx + 1) % 100 == 0:
        print(idx+1)
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 184.18245440000464
